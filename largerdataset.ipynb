# %%
import pandas as pd

# Load the dataset
dataset_1 = pd.read_excel('Hospital Patient Dataset Validata.xlsx')
dataset_2 = pd.read_excel('Larger Dataset.xlsx')

# Function to validate a single dataset
def validate_dataset(dataset, dataset_name):
    print(f"\n=== Validating Dataset: {dataset_name} ===")

    # Main function to execute all validations
    # Validate 'Staging-T Category'
    print("Validating for DiagStaging_StagingTCategory")
    recognized_staging_t_category = find_equivalent_column(
        dataset, 'DiagStaging_StagingTCategory', ["Staging-T Category", "T Category"]
    )
    if recognized_staging_t_category:
        validate_column_values(
            dataset, recognized_staging_t_category, 
            ["Clinical", "Pathologic", "Radiographic"], 
            'Invalid Staging-T Category'
        )
        validate_missing_values(dataset, recognized_staging_t_category)

    # Validate 'Staging-T'
    print("Validating for DiagStaging_StagingT")
    recognized_staging_t = find_equivalent_column(
        dataset, 'DiagStaging_StagingT', ["Staging-T", "T Staging", "Tumor Staging"]
    )
    if recognized_staging_t:
        validate_column_values(
            dataset, recognized_staging_t, 
            ["T1a", "T1b", "T1c", "T2a", "T2b", "T2c", "T3a", "T3b", "T4", 
             "Tx (only if prostate has been removed)", "Information Not Available"], 
            'Invalid Staging-T Value'
        )
        validate_missing_values(dataset, recognized_staging_t)

    # Validate 'Staging-N'
    print("Validating for DiagStaging_StagingN")
    recognized_staging_n = find_equivalent_column(
        dataset, 'DiagStaging_StagingN', ["Staging-N", "Staging N"]
    )
    if recognized_staging_n:
        validate_column_values(
            dataset, recognized_staging_n, 
            ["N0", "N1", "Nx", "Information Not Available"], 
            'Invalid Staging-N Value'
        )
        validate_missing_values(dataset, recognized_staging_n)

    # Validate 'Staging-M'
    print("Validating for DiagStaging_StagingM")
    recognized_staging_m = find_equivalent_column(
        dataset, 'DiagStaging_StagingM', ["Staging-M", "Staging M"]
    )
    if recognized_staging_m:
        validate_column_values(
            dataset, recognized_staging_m, 
            ["M0", "M1a", "M1b", "M1c", "Mx", "Information Not Available"], 
            'Invalid Staging-M Value'
        )
        validate_missing_values(dataset, recognized_staging_m)

    # Validate 'Imaging for Biopsy'
    print("Validating for DiagStaging_ImagingBiopsy")
    recognized_imaging_biopsy = find_equivalent_column(
        dataset, 'DiagStaging_ImagingBiopsy', ["Imaging for Biopsy", "Biopsy Imaging"]
    )
    if recognized_imaging_biopsy:
        validate_column_values(
            dataset, recognized_imaging_biopsy, 
            ["Ultrasound", "Magnetic Resonance Imaging", "Computed Tomography"], 
            'Invalid Imaging for Biopsy value'
        )
        validate_missing_values(dataset, recognized_imaging_biopsy)

    # Validate 'Pathology Molecular Test Name'
    print("Validating for DiagStaging_PathologyMolecularTestName")
    recognized_pathology_test = find_equivalent_column(
        dataset, 'DiagStaging_PathologyMolecularTestName', 
        ["Pathology Molecular Test Name", "Molecular Test Name"]
    )
    if recognized_pathology_test:
        validate_column_values(
            dataset, recognized_pathology_test, 
            ["DECIPHER", "Prolaris", "Oncotype DX Genomic Prostate Score", 
             "ProMark", "(+ Other)"], 
            'Invalid Pathology Molecular Test Name'
        )
        validate_missing_values(dataset, recognized_pathology_test)

    # Validate 'Pathology Molecular Test Result'
    print("Validating for DiagStaging_PathologyMolecularTestResult")
    recognized_test_result = find_equivalent_column(
        dataset, 'DiagStaging_PathologyMolecularTestResult', 
        ["Pathology Molecular Test Result", "Molecular Test Result"]
    )
    if recognized_test_result:
        invalid_test_result = convert_or_flag_pathology_test_result_values(dataset, recognized_test_result)
        if not invalid_test_result.empty:
            print(f"2. {len(invalid_test_result)} rows have an invalid Pathology Molecular Test Result value:")
            print(f"   Row numbers: {', '.join(map(str, invalid_test_result['Row']))}\n")
            print(invalid_test_result.to_string(index=False))
        else:
            print("2. No rows with invalid Pathology Molecular Test Result values found.\n")
        validate_missing_values(dataset, recognized_test_result)

    # Validate 'Treatment Outcome'
    print("Validating for PatientTreatmentOutcome_DiseaseStatus")
    recognized_outcome = find_equivalent_column(
        dataset, 'PatientTreatmentOutcome_DiseaseStatus', ["Treatment Outcome", "Outcome"]
    )
    if recognized_outcome:
        invalid_outcomes = validate_treatment_outcome_values(dataset, recognized_outcome)
        if not invalid_outcomes.empty:
            print(f"2. {len(invalid_outcomes)} rows have an invalid Treatment Outcome value:")
            invalid_row_numbers = ', '.join(map(str, invalid_outcomes['Row'].tolist()))
            print(f"   Row numbers: {invalid_row_numbers}\n")
            print(invalid_outcomes.to_string(index=False))
        else:
            print("2. No rows with invalid Treatment Outcome values found.\n")
        validate_missing_values(dataset, recognized_outcome, allow_null=False)

    # Validate 'Start Date of Treatment'
    print("Validating for DiagStagingTreatmentOverview_DateOfRecord")
    recognized_column_start_date = find_equivalent_column(
        dataset, 'DiagStagingTreatmentOverview_DateOfRecord',
        ["Start Date of Treatment", "Treatment Start Date"]
    )
    if recognized_column_start_date:
        invalid_start_dates = convert_or_flag_start_dates(dataset, recognized_column_start_date)
        if not invalid_start_dates.empty:
            print(f"2. {len(invalid_start_dates)} rows have an invalid Start Date of Treatment:")
            invalid_row_numbers = ', '.join(map(str, invalid_start_dates['Row'].tolist()))
            print(f"   Row numbers: {invalid_row_numbers}\n")
            print(invalid_start_dates.to_string(index=False))
        else:
            print("2. No rows with invalid Start Date of Treatment values found.\n")
        validate_missing_values(dataset, recognized_column_start_date, allow_null=False)

    # Validate 'End Date of Treatment'
    print("Validating for PatientTreatmentOutcome_DateOfRecord")
    recognized_column_end_date = find_equivalent_column(
        dataset, 'PatientTreatmentOutcome_DateOfRecord', ["End Date of Treatment", "Treatment End Date"]
    )
    if recognized_column_end_date:
        invalid_end_dates = convert_or_flag_end_dates(dataset, recognized_column_end_date)
        if not invalid_end_dates.empty:
            print(f"2. {len(invalid_end_dates)} rows have an invalid End Date of Treatment:")
            invalid_row_numbers = ', '.join(map(str, invalid_end_dates['Row'].tolist()))
            print(f"   Row numbers: {invalid_row_numbers}\n")
            print(invalid_end_dates.to_string(index=False))
        else:
            print("2. No rows with invalid End Date of Treatment values found.\n")
        validate_missing_end_dates(dataset, recognized_column_end_date)

# Function to recognize and validate column names with alternatives
def find_equivalent_column(data, expected_column, alternative_names):
    for col in data.columns:
        if col in alternative_names:
            print(f"1. Recognized '{col}' as '{expected_column}' for validation, but the column name is incorrect.")
            print(f"   The correct column name should be '{expected_column}'")
            return col
    print(f"1. Column name mismatch: Expected '{expected_column}', but not found.")
    print(f"   Found columns: {list(data.columns)}")
    return None

# Function to validate a column's values against allowed values
def validate_column_values(data, column, valid_values, error_message):
    invalid_values = [
        {
            'Row': index,
            'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
            column: row[column],
            'Error': error_message
        }
        for index, row in data.iterrows()
        if pd.notna(row[column]) and row[column] not in valid_values
    ]

    if invalid_values:
        print(f"2. {len(invalid_values)} rows have an invalid '{column}' value:")
        print(f"   Row numbers: {', '.join(str(val['Row']) for val in invalid_values)}\n")
        print(pd.DataFrame(invalid_values).to_string(index=False))
    else:
        print(f"2. No rows with invalid '{column}' values found.\n")

# Function to flag invalid Pathology Molecular Test Results (must be a string)
def convert_or_flag_pathology_test_result_values(data, column):
    invalid_pathology_test_result = []

    for index, row in data.iterrows():
        test_result = row[column]
        if pd.notna(test_result) and not isinstance(test_result, str):
            invalid_pathology_test_result.append({
                'Row': index,
                'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
                column: test_result,
                'Error': 'Invalid format for Pathology Molecular Test Result'
            })

    return pd.DataFrame(invalid_pathology_test_result)

# Function to validate 'Treatment Outcome'
def validate_treatment_outcome_values(data, outcome_column):
    valid_values = [
        "Under Treatment", "No evidence of disease (NED)", "Stable Disease",
        "Partial Response", "Progressive Disease", 
        "Indeterminate (possible pseudo-progression)", "Complete Response", 
        "Biochemical Recurrence", "Primary Recurrence", "Local Recurrence", 
        "Nodal Recurrence", "Distant Recurrence", "(+Other)"
    ]
    invalid_outcomes = [
        {
            'Row': index,
            'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
            outcome_column: row[outcome_column],
            'Error': 'Invalid Treatment Outcome value'
        }
        for index, row in data.iterrows()
        if pd.notna(row[outcome_column]) and row[outcome_column] not in valid_values
    ]

    return pd.DataFrame(invalid_outcomes)

# Function to validate 'Start Date of Treatment' values
def convert_or_flag_start_dates(data, start_date_column):
    invalid_start_dates = []

    for index, row in data.iterrows():
        start_date = row[start_date_column]
        if isinstance(start_date, str):
            try:
                parsed_date = pd.to_datetime(start_date, format='%Y-%m-%d', errors='raise')
                data.at[index, start_date_column] = parsed_date.replace(hour=0, minute=0, second=0)
            except Exception:
                invalid_start_dates.append({
                    'Row': index,
                    'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
                    start_date_column: start_date,
                    'Error': 'Invalid date format'
                })

    return pd.DataFrame(invalid_start_dates)

# Function to check for missing values in a specific column
def validate_missing_values(data, column, allow_null=True):
    missing_rows = data[data[column].isna()]
    if not missing_rows.empty:
        print(f"3. Rows with missing '{column}':")
        print(missing_rows[['Anonymized Patient Identifier', column]].to_string(index=False))
    else:
        null_msg = " (null values are allowed)" if allow_null else ""
        print(f"3. No missing '{column}' values found{null_msg}.\n")

# Step 1: Recognize and validate the 'End Date of Treatment' column
def find_equivalent_column_end_date(data, expected_column):
    alternative_names = ["End Date of Treatment", "Treatment End Date"]  # Add more alternatives if needed
    for col in data.columns:
        if col in alternative_names:
            print(f"1. Recognized '{col}' as '{expected_column}' for validation, but the column name is incorrect.")
            print(f"   The correct column name should be: '{expected_column}'")
            return col  # Return the recognized column
    print(f"1. Column name mismatch: Expected '{expected_column}', but not found in dataset.")
    print(f"   Found columns: {list(data.columns)}")
    print(f"   The correct column name should be: '{expected_column}'")
    return None

# Step 2: Validate 'End Date of Treatment' values and set time to midnight if missing
def convert_or_flag_end_dates(data, end_date_column):
    invalid_end_dates = []

    for index, row in data.iterrows():
        end_date = row[end_date_column]

        # Check if the date is a string and try to convert to datetime
        if isinstance(end_date, str):
            try:
                # Attempt to parse date-only format and set time to midnight (ISO 8601 compatible)
                parsed_date = pd.to_datetime(end_date, format='%Y-%m-%d', errors='raise')
                data.at[index, end_date_column] = parsed_date.replace(hour=0, minute=0, second=0)
            except Exception:
                invalid_end_dates.append({
                    'Row': index,
                    'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
                    end_date_column: end_date,
                    'Error': 'Invalid date format'
                })

    return pd.DataFrame(invalid_end_dates)

# Step 3: Check for missing 'End Date of Treatment' values
def validate_missing_end_dates(data, end_date_column):
    missing_end_dates = data[data[end_date_column].isna()]
    if not missing_end_dates.empty:
        print(f"3. Rows with missing '{end_date_column}':")
        print(missing_end_dates[['Anonymized Patient Identifier', end_date_column]])
    else:
        print(f"3. No missing '{end_date_column}' values found (null values are not allowed).")


def main():
    validate_dataset(dataset_1, "Hospital Patient Dataset Validata")
    print("\n----------------------------------------\n")
    validate_dataset(dataset_2, "Larger Dataset")

# Execute the main function
if __name__ == "__main__":
    main()
# Out:
# === Validating Dataset: Hospital Patient Dataset Validata ===
# Validating for DiagStaging_StagingTCategory
# 1. Recognized 'Staging-T Category' as 'DiagStaging_StagingTCategory' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_StagingTCategory'
# 2. No rows with invalid 'Staging-T Category' values found.
#
# 3. No missing 'Staging-T Category' values found (null values are allowed).
#
# Validating for DiagStaging_StagingT
# 1. Recognized 'Staging-T' as 'DiagStaging_StagingT' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_StagingT'
# 2. No rows with invalid 'Staging-T' values found.
#
# 3. No missing 'Staging-T' values found (null values are allowed).
#
# Validating for DiagStaging_StagingN
# 1. Recognized 'Staging-N' as 'DiagStaging_StagingN' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_StagingN'
# 2. No rows with invalid 'Staging-N' values found.
#
# 3. No missing 'Staging-N' values found (null values are allowed).
#
# Validating for DiagStaging_StagingM
# 1. Recognized 'Staging-M' as 'DiagStaging_StagingM' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_StagingM'
# 2. No rows with invalid 'Staging-M' values found.
#
# 3. No missing 'Staging-M' values found (null values are allowed).
#
# Validating for DiagStaging_ImagingBiopsy
# 1. Recognized 'Imaging for Biopsy' as 'DiagStaging_ImagingBiopsy' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_ImagingBiopsy'
# 2. No rows with invalid 'Imaging for Biopsy' values found.
#
# 3. No missing 'Imaging for Biopsy' values found (null values are allowed).
#
# Validating for DiagStaging_PathologyMolecularTestName
# 1. Recognized 'Pathology Molecular Test Name' as 'DiagStaging_PathologyMolecularTestName' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_PathologyMolecularTestName'
# 2. No rows with invalid 'Pathology Molecular Test Name' values found.
#
# 3. No missing 'Pathology Molecular Test Name' values found (null values are allowed).
#
# Validating for DiagStaging_PathologyMolecularTestResult
# 1. Recognized 'Pathology Molecular Test Result' as 'DiagStaging_PathologyMolecularTestResult' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_PathologyMolecularTestResult'
# 2. No rows with invalid Pathology Molecular Test Result values found.
#
# 3. No missing 'Pathology Molecular Test Result' values found (null values are allowed).
#
# Validating for PatientTreatmentOutcome_DiseaseStatus
# 1. Recognized 'Treatment Outcome' as 'PatientTreatmentOutcome_DiseaseStatus' for validation, but the column name is incorrect.
#    The correct column name should be 'PatientTreatmentOutcome_DiseaseStatus'
# 2. 6 rows have an invalid Treatment Outcome value:
#    Row numbers: 48, 124, 141, 202, 237, 262
#
#  Row Anonymized Patient Identifier Treatment Outcome                           Error
#   48                     Anon58131     Stble Disease Invalid Treatment Outcome value
#  124                     Anon22499     Stble Disease Invalid Treatment Outcome value
#  141                     Anon18169     Stble Disease Invalid Treatment Outcome value
#  202                           NaN     Stble Disease Invalid Treatment Outcome value
#  237                     Anon50361     Stble Disease Invalid Treatment Outcome value
#  262                     Anon82003     Stble Disease Invalid Treatment Outcome value
# 3. No missing 'Treatment Outcome' values found.
#
# Validating for DiagStagingTreatmentOverview_DateOfRecord
# 1. Recognized 'Start Date of Treatment' as 'DiagStagingTreatmentOverview_DateOfRecord' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStagingTreatmentOverview_DateOfRecord'
# 2. No rows with invalid Start Date of Treatment values found.
#
# 3. No missing 'Start Date of Treatment' values found.
#
# Validating for PatientTreatmentOutcome_DateOfRecord
# 1. Recognized 'End Date of Treatment' as 'PatientTreatmentOutcome_DateOfRecord' for validation, but the column name is incorrect.
#    The correct column name should be 'PatientTreatmentOutcome_DateOfRecord'
# 2. No rows with invalid End Date of Treatment values found.
#
# 3. No missing 'End Date of Treatment' values found (null values are not allowed).
#
# ----------------------------------------
#
#
# === Validating Dataset: Larger Dataset ===
# Validating for DiagStaging_StagingTCategory
# 1. Recognized 'Staging-T Category' as 'DiagStaging_StagingTCategory' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_StagingTCategory'
# 2. No rows with invalid 'Staging-T Category' values found.
#
# 3. No missing 'Staging-T Category' values found (null values are allowed).
#
# Validating for DiagStaging_StagingT
# 1. Recognized 'Staging-T' as 'DiagStaging_StagingT' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_StagingT'
# 2. No rows with invalid 'Staging-T' values found.
#
# 3. No missing 'Staging-T' values found (null values are allowed).
#
# Validating for DiagStaging_StagingN
# 1. Recognized 'Staging-N' as 'DiagStaging_StagingN' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_StagingN'
# 2. No rows with invalid 'Staging-N' values found.
#
# 3. No missing 'Staging-N' values found (null values are allowed).
#
# Validating for DiagStaging_StagingM
# 1. Recognized 'Staging-M' as 'DiagStaging_StagingM' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging
#   38                     Anon37279                      Decipher Invalid Pathology Molecular Test Name
#   39                     Anon62722                      Decipher Invalid Pathology Molecular Test Name
#   40                     Anon83204                   Oncotype DX Invalid Pathology Molecular Test Name
#   42                     Anon37344                      Decipher Invalid Pathology Molecular Test Name
#   45                     Anon34127                   Oncotype DX Invalid Pathology Molecular Test Name
#   48                     Anon36871                      Decipher Invalid Pathology Molecular Test Name
#   50                     Anon86328                      Decipher Invalid Pathology Molecular Test Name
#   52                     Anon99763                   Oncotype DX Invalid Pathology Molecular Test Name
#   54                     Anon43001                   Oncotype DX Invalid Pathology Molecular Test Name
#   55                     Anon98370                      Decipher Invalid Pathology Molecular Test Name
#   56                     Anon20484                      Decipher Invalid Pathology Molecular Test Name
#   57                     Anon18365                   Oncotype DX Invalid Pathology Molecular Test Name
#   63                     Anon23285                   Oncotype DX Invalid Pathology Molecular Test Name
#   64                     Anon95177                   Oncotype DX Invalid Pathology Molecular Test Name
#   65                     Anon62336                   Oncotype DX Invalid Pathology Molecular Test Name
#   66                     Anon56366                      Decipher Invalid Pathology Molecular Test Name
#   67                     Anon16453                   Oncotype DX Invalid Pathology Molecular Test Name
#   68                     Anon66554                      Decipher Invalid Pathology Molecular Test Name
#   69                     Anon48909                   Oncotype DX Invalid Pathology Molecular Test Name
#   72                     Anon13378                   Oncotype DX Invalid Pathology Molecular Test Name
#   73                     Anon55254                      Decipher Invalid Pathology Molecular Test Name
#   76                     Anon62960                      Decipher Invalid Pathology Molecular Test Name
#   77                     Anon84707                      Decipher Invalid Pathology Molecular Test Name
#   78                     Anon65801                      Decipher Invalid Pathology Molecular Test Name
#   80                     Anon23095                      Decipher Invalid Pathology Molecular Test Name
#   81                     Anon46167                      Decipher Invalid Pathology Molecular Test Name
#   82                     Anon77013                   Oncotype DX Invalid Pathology Molecular Test Name
#   83                     Anon28458                      Decipher Invalid Pathology Molecular Test Name
#   85                     Anon83141                      Decipher Invalid Pathology Molecular Test Name
#   87                     Anon69780                   Oncotype DX Invalid Pathology Molecular Test Name
#   89                     Anon54436                   Oncotype DX Invalid Pathology Molecular Test Name
#   91                     Anon42305                      Decipher Invalid Pathology Molecular Test Name
#   92                     Anon91870                   Oncotype DX Invalid Pathology Molecular Test Name
#   93                     Anon42468                   Oncotype DX Invalid Pathology Molecular Test Name
#   94                     Anon14838                   Oncotype DX Invalid Pathology Molecular Test Name
#   97                     Anon93108                      Decipher Invalid Pathology Molecular Test Name
#  101                     Anon46502                   Oncotype DX Invalid Pathology Molecular Test Name
#  104                     Anon72147                      Decipher Invalid Pathology Molecular Test Name
#  108                     Anon56132                      Decipher Invalid Pathology Molecular Test Name
#  109                     Anon35167                      Decipher Invalid Pathology Molecular Test Name
#  111                     Anon74314                      Decipher Invalid Pathology Molecular Test Name
#  112                     Anon41736                      Decipher Invalid Pathology Molecular Test Name
#  113                     Anon24764                      Decipher Invalid Pathology Molecular Test Name
#  114                     Anon73375                      Decipher Invalid Pathology Molecular Test Name
#  115                     Anon48142                      Decipher Invalid Pathology Molecular Test Name
#  117                     Anon18649                      Decipher Invalid Pathology Molecular Test Name
#  119                     Anon54848                      Decipher Invalid Pathology Molecular Test Name
#  120                     Anon27328                      Decipher Invalid Pathology Molecular Test Name
#  121                     Anon23395                      Decipher Invalid Pathology Molecular Test Name
#  125                     Anon66803                   Oncotype DX Invalid Pathology Molecular Test Name
#  126                     Anon88845                   Oncotype DX Invalid Pathology Molecular Test Name
#  128                     Anon65027                      Decipher Invalid Pathology Molecular Test Name
#  129                     Anon10937                   Oncotype DX Invalid Pathology Molecular Test Name
#  130                     Anon85731                   Oncotype DX Invalid Pathology Molecular Test Name
#  131                     Anon87019                      Decipher Invalid Pathology Molecular Test Name
#  133                     Anon15169                      Decipher Invalid Pathology Molecular Test Name
#  134                     Anon71612                   Oncotype DX Invalid Pathology Molecular Test Name
#  135                     Anon34927                      Decipher Invalid Pathology Molecular Test Name
#  136                     Anon90858                      Decipher Invalid Pathology Molecular Test Name
#  137                     Anon91275                   Oncotype DX Invalid Pathology Molecular Test Name
#  138                     Anon58609                      Decipher Invalid Pathology Molecular Test Name
#  139                     Anon57704                      Decipher Invalid Pathology Molecular Test Name
#  140                     Anon23128                   Oncotype DX Invalid Pathology Molecular Test Name
#  141                     Anon40488                   Oncotype DX Invalid Pathology Molecular Test Name
#  143                     Anon13082                   Oncotype DX Invalid Pathology Molecular Test Name
#  149                     Anon80936                   Oncotype DX Invalid Pathology Molecular Test Name
#  150                     Anon78206                      Decipher Invalid Pathology Molecular Test Name
#  152                     Anon35492                      Decipher Invalid Pathology Molecular Test Name
#  154                     Anon87997                      Decipher Invalid Pathology Molecular Test Name
#  155                     Anon48657                      Decipher Invalid Pathology Molecular Test Name
#  157                     Anon28442                   Oncotype DX Invalid Pathology Molecular Test Name
#  160                     Anon98008                   Oncotype DX Invalid Pathology Molecular Test Name
#  162                     Anon56625                      Decipher Invalid Pathology Molecular Test Name
#  166                     Anon50985                   Oncotype DX Invalid Pathology Molecular Test Name
#  169                     Anon74154                   Oncotype DX Invalid Pathology Molecular Test Name
#  170                     Anon14725                   Oncotype DX Invalid Pathology Molecular Test Name
#  172                     Anon61825                      Decipher Invalid Pathology Molecular Test Name
#  173                     Anon43236                   Oncotype DX Invalid Pathology Molecular Test Name
#  175                     Anon27917                      Decipher Invalid Pathology Molecular Test Name
#  176                     Anon58123                   Oncotype DX Invalid Pathology Molecular Test Name
#  177                     Anon64208                   Oncotype DX Invalid Pathology Molecular Test Name
#  179                     Anon76619                   Oncotype DX Invalid Pathology Molecular Test Name
#  180                     Anon57694                   Oncotype DX Invalid Pathology Molecular Test Name
#  181                     Anon18902                   Oncotype DX Invalid Pathology Molecular Test Name
#  183                     Anon13742                      Decipher Invalid Pathology Molecular Test Name
#  185                     Anon24350                   Oncotype DX Invalid Pathology Molecular Test Name
#  189                     Anon20642                   Oncotype DX Invalid Pathology Molecular Test Name
#  190                     Anon49309                      Decipher Invalid Pathology Molecular Test Name
#  195                     Anon20332                      Decipher Invalid Pathology Molecular Test Name
#  196                     Anon50849                   Oncotype DX Invalid Pathology Molecular Test Name
#  197                     Anon53446                   Oncotype DX Invalid Pathology Molecular Test Name
#  198                     Anon46158                      Decipher Invalid Pathology Molecular Test Name
#  199                     Anon17432                      Decipher Invalid Pathology Molecular Test Name
#  200                     Anon42092                   Oncotype DX Invalid Pathology Molecular Test Name
#  203                     Anon45629                      Decipher Invalid Pathology Molecular Test Name
#  204                     Anon23453                   Oncotype DX Invalid Pathology Molecular Test Name
#  206                     Anon43407                      Decipher Invalid Pathology Molecular Test Name
#  209                     Anon33999                      Decipher Invalid Pathology Molecular Test Name
#  210                     Anon30345                      Decipher Invalid Pathology Molecular Test Name
#  211                     Anon57704                   Oncotype DX Invalid Pathology Molecular Test Name
#  213                     Anon84468                   Oncotype DX Invalid Pathology Molecular Test Name
#  214                     Anon28255                      Decipher Invalid Pathology Molecular Test Name
#  215                     Anon27881                      Decipher Invalid Pathology Molecular Test Name
#  216                     Anon75453                      Decipher Invalid Pathology Molecular Test Name
#  217                     Anon19699                      Decipher Invalid Pathology Molecular Test Name
#  219                     Anon34022                      Decipher Invalid Pathology Molecular Test Name
#  221                     Anon11237                   Oncotype DX Invalid Pathology Molecular Test Name
#  225                     Anon20250                      Decipher Invalid Pathology Molecular Test Name
#  228                     Anon48482                      Decipher Invalid Pathology Molecular Test Name
#  229                     Anon98354                      Decipher Invalid Pathology Molecular Test Name
#  231                     Anon60447                      Decipher Invalid Pathology Molecular Test Name
#  232                     Anon31444                      Decipher Invalid Pathology Molecular Test Name
#  234                     Anon97764                   Oncotype DX Invalid Pathology Molecular Test Name
#  235                     Anon73816                   Oncotype DX Invalid Pathology Molecular Test Name
#  236                     Anon76617                      Decipher Invalid Pathology Molecular Test Name
#  238                     Anon27190                   Oncotype DX Invalid Pathology Molecular Test Name
#  239                     Anon93568                      Decipher Invalid Pathology Molecular Test Name
#  241                     Anon47446                   Oncotype DX Invalid Pathology Molecular Test Name
#  243                     Anon35223                   Oncotype DX Invalid Pathology Molecular Test Name
#  244                     Anon78258                   Oncotype DX Invalid Pathology Molecular Test Name
#  245                     Anon25127                      Decipher Invalid Pathology Molecular Test Name
#  246                     Anon31694                      Decipher Invalid Pathology Molecular Test Name
#  247                     Anon84995                   Oncotype DX Invalid Pathology Molecular Test Name
#  249                     Anon92271                      Decipher Invalid Pathology Molecular Test Name
#  250                     Anon66888                      Decipher Invalid Pathology Molecular Test Name
#  251                     Anon66871                      Decipher Invalid Pathology Molecular Test Name
#  252                     Anon17498                      Decipher Invalid Pathology Molecular Test Name
#  253                     Anon45325                      Decipher Invalid Pathology Molecular Test Name
#  254                     Anon11567                   Oncotype DX Invalid Pathology Molecular Test Name
#  255                     Anon13589                   Oncotype DX Invalid Pathology Molecular Test Name
#  256                     Anon85966                      Decipher Invalid Pathology Molecular Test Name
#  258                     Anon86601                   Oncotype DX Invalid Pathology Molecular Test Name
#  259                     Anon39508                   Oncotype DX Invalid Pathology Molecular Test Name
#  260                     Anon65437                   Oncotype DX Invalid Pathology Molecular Test Name
#  265                     Anon71613                      Decipher Invalid Pathology Molecular Test Name
#  267                     Anon19982                      Decipher Invalid Pathology Molecular Test Name
#  269                     Anon21378                   Oncotype DX Invalid Pathology Molecular Test Name
#  270                     Anon79880                   Oncotype DX Invalid Pathology Molecular Test Name
#  271                     Anon44634                   Oncotype DX Invalid Pathology Molecular Test Name
#  272                     Anon94712                      Decipher Invalid Pathology Molecular Test Name
#  273                     Anon71095                      Decipher Invalid Pathology Molecular Test Name
#  274                     Anon47097                      Decipher Invalid Pathology Molecular Test Name
#  277                     Anon18138                   Oncotype DX Invalid Pathology Molecular Test Name
#  279                     Anon51646                   Oncotype DX Invalid Pathology Molecular Test Name
#  281                     Anon42750                      Decipher Invalid Pathology Molecular Test Name
#  283                     Anon21814                      Decipher Invalid Pathology Molecular Test Name
#  284                     Anon97929                      Decipher Invalid Pathology Molecular Test Name
#  286                     Anon26652                   Oncotype DX Invalid Pathology Molecular Test Name
#  288                     Anon64718                   Oncotype DX Invalid Pathology Molecular Test Name
#  289                     Anon49209                   Oncotype DX Invalid Pathology Molecular Test Name
#  290                     Anon86429                   Oncotype DX Invalid Pathology Molecular Test Name
#  292                     Anon39052                   Oncotype DX Invalid Pathology Molecular Test Name
#  294                     Anon67967                      Decipher Invalid Pathology Molecular Test Name
#  296                     Anon48937                      Decipher Invalid Pathology Molecular Test Name
#  297                     Anon93138                   Oncotype DX Invalid Pathology Molecular Test Name
#  298                     Anon50392                      Decipher Invalid Pathology Molecular Test Name
#  299                     Anon99905                      Decipher Invalid Pathology Molecular Test Name
#  300                     Anon92997                      Decipher Invalid Pathology Molecular Test Name
#  301                     Anon98015                   Oncotype DX Invalid Pathology Molecular Test Name
#  302                     Anon57054                   Oncotype DX Invalid Pathology Molecular Test Name
#  304                     Anon39065                   Oncotype DX Invalid Pathology Molecular Test Name
#  305                     Anon76015                   Oncotype DX Invalid Pathology Molecular Test Name
#  307                     Anon37367                   Oncotype DX Invalid Pathology Molecular Test Name
#  310                     Anon65628                   Oncotype DX Invalid Pathology Molecular Test Name
#  311                     Anon95688                   Oncotype DX Invalid Pathology Molecular Test Name
#  313                     Anon91515                   Oncotype DX Invalid Pathology Molecular Test Name
#  314                     Anon86632                      Decipher Invalid Pathology Molecular Test Name
#  315                     Anon52025                   Oncotype DX Invalid Pathology Molecular Test Name
#  316                     Anon34025                      Decipher Invalid Pathology Molecular Test Name
#  318                     Anon29824                      Decipher Invalid Pathology Molecular Test Name
#  319                     Anon51831                      Decipher Invalid Pathology Molecular Test Name
#  321                     Anon71988                   Oncotype DX Invalid Pathology Molecular Test Name
#  322                     Anon72306                   Oncotype DX Invalid Pathology Molecular Test Name
#  324                     Anon48793                   Oncotype DX Invalid Pathology Molecular Test Name
#  325                     Anon33675                   Oncotype DX Invalid Pathology Molecular Test Name
#  326                     Anon30665                      Decipher Invalid Pathology Molecular Test Name
#  328                     Anon63900                   Oncotype DX Invalid Pathology Molecular Test Name
#  331                     Anon59852                      Decipher Invalid Pathology Molecular Test Name
#  333                     Anon81879                   Oncotype DX Invalid Pathology Molecular Test Name
#  337                     Anon25968                      Decipher Invalid Pathology Molecular Test Name
#  339                     Anon57103                      Decipher Invalid Pathology Molecular Test Name
#  340                     Anon47559                      Decipher Invalid Pathology Molecular Test Name
#  341                     Anon98211                   Oncotype DX Invalid Pathology Molecular Test Name
#  343                     Anon27610                   Oncotype DX Invalid Pathology Molecular Test Name
#  344                     Anon61090                      Decipher Invalid Pathology Molecular Test Name
#  346                     Anon52317                      Decipher Invalid Pathology Molecular Test Name
#  348                     Anon39986                   Oncotype DX Invalid Pathology Molecular Test Name
#  349                     Anon75960                   Oncotype DX Invalid Pathology Molecular Test Name
#  350                     Anon57612                      Decipher Invalid Pathology Molecular Test Name
#  352                     Anon55849                      Decipher Invalid Pathology Molecular Test Name
#  353                     Anon80969                      Decipher Invalid Pathology Molecular Test Name
#  354                     Anon75558                   Oncotype DX Invalid Pathology Molecular Test Name
#  355                     Anon54322                   Oncotype DX Invalid Pathology Molecular Test Name
#  356                     Anon84913                   Oncotype DX Invalid Pathology Molecular Test Name
#  357                     Anon87274                   Oncotype DX Invalid Pathology Molecular Test Name
#  360                     Anon79390                      Decipher Invalid Pathology Molecular Test Name
#  361                     Anon84211                   Oncotype DX Invalid Pathology Molecular Test Name
#  364                     Anon45100                   Oncotype DX Invalid Pathology Molecular Test Name
#  366                     Anon70191                      Decipher Invalid Pathology Molecular Test Name
#  367                     Anon99659                   Oncotype DX Invalid Pathology Molecular Test Name
#  368                     Anon43036                      Decipher Invalid Pathology Molecular Test Name
#  370                     Anon90846                      Decipher Invalid Pathology Molecular Test Name
#  371                     Anon85660                      Decipher Invalid Pathology Molecular Test Name
#  372                     Anon55799                   Oncotype DX Invalid Pathology Molecular Test Name
#  373                     Anon82727                   Oncotype DX Invalid Pathology Molecular Test Name
#  374                     Anon53826                      Decipher Invalid Pathology Molecular Test Name
#  376                     Anon89648                   Oncotype DX Invalid Pathology Molecular Test Name
#  377                     Anon23751                   Oncotype DX Invalid Pathology Molecular Test Name
#  378                     Anon26210                   Oncotype DX Invalid Pathology Molecular Test Name
#  379                     Anon19211                      Decipher Invalid Pathology Molecular Test Name
#  380                     Anon39243                   Oncotype DX Invalid Pathology Molecular Test Name
#  383                     Anon37218                   Oncotype DX Invalid Pathology Molecular Test Name
#  384                     Anon28990                      Decipher Invalid Pathology Molecular Test Name
#  385                     Anon20745                   Oncotype DX Invalid Pathology Molecular Test Name
#  386                     Anon34425                   Oncotype DX Invalid Pathology Molecular Test Name
#  388                     Anon65939                      Decipher Invalid Pathology Molecular Test Name
#  390                     Anon94938                   Oncotype DX Invalid Pathology Molecular Test Name
#  392                     Anon64995                   Oncotype DX Invalid Pathology Molecular Test Name
#  393                     Anon28270                      Decipher Invalid Pathology Molecular Test Name
#  394                     Anon56722                      Decipher Invalid Pathology Molecular Test Name
#  396                     Anon85321                   Oncotype DX Invalid Pathology Molecular Test Name
#  397                     Anon69715                   Oncotype DX Invalid Pathology Molecular Test Name
#  399                     Anon98980                      Decipher Invalid Pathology Molecular Test Name
#  400                     Anon23094                      Decipher Invalid Pathology Molecular Test Name
#  401                     Anon93802                      Decipher Invalid Pathology Molecular Test Name
#  402                     Anon13947                      Decipher Invalid Pathology Molecular Test Name
#  403                     Anon29399                      Decipher Invalid Pathology Molecular Test Name
#  404                     Anon93605                      Decipher Invalid Pathology Molecular Test Name
#  405                     Anon96802                   Oncotype DX Invalid Pathology Molecular Test Name
#  406                     Anon88788                      Decipher Invalid Pathology Molecular Test Name
#  407                     Anon77805                   Oncotype DX Invalid Pathology Molecular Test Name
#  409                     Anon42572                   Oncotype DX Invalid Pathology Molecular Test Name
#  410                     Anon38637                      Decipher Invalid Pathology Molecular Test Name
#  412                     Anon28806                      Decipher Invalid Pathology Molecular Test Name
#  414                     Anon52710                   Oncotype DX Invalid Pathology Molecular Test Name
# ...
#  782                     Anon82436                   Oncotype DX Invalid Pathology Molecular Test Name
#  783                     Anon76695                   Oncotype DX Invalid Pathology Molecular Test Name
#  789                     Anon29003                      Decipher Invalid Pathology Molecular Test Name
#  790                     Anon73252                   Oncotype DX Invalid Pathology Molecular Test Name
#  794                     Anon23207                      Decipher Invalid Pathology Molecular Test Name
#  796                     Anon94009                   Oncotype DX Invalid Pathology Molecular Test Name
#  797                     Anon25592                      Decipher Invalid Pathology Molecular Test Name
#  798                     Anon78390                   Oncotype DX Invalid Pathology Molecular Test Name
#  799                     Anon57595                   Oncotype DX Invalid Pathology Molecular Test Name
#  802                     Anon41136                      Decipher Invalid Pathology Molecular Test Name
#  803                     Anon41049                   Oncotype DX Invalid Pathology Molecular Test Name
#  804                     Anon37041                   Oncotype DX Invalid Pathology Molecular Test Name
#  806                     Anon98336                      Decipher Invalid Pathology Molecular Test Name
#  808                     Anon24401                      Decipher Invalid Pathology Molecular Test Name
#  809                     Anon62609                      Decipher Invalid Pathology Molecular Test Name
#  810                     Anon75373                      Decipher Invalid Pathology Molecular Test Name
#  811                     Anon33542                      Decipher Invalid Pathology Molecular Test Name
#  813                     Anon16145                      Decipher Invalid Pathology Molecular Test Name
#  814                     Anon14561                      Decipher Invalid Pathology Molecular Test Name
#  815                     Anon40753                   Oncotype DX Invalid Pathology Molecular Test Name
#  816                     Anon69283                      Decipher Invalid Pathology Molecular Test Name
#  817                     Anon28418                   Oncotype DX Invalid Pathology Molecular Test Name
#  818                     Anon99123                   Oncotype DX Invalid Pathology Molecular Test Name
#  819                     Anon50210                   Oncotype DX Invalid Pathology Molecular Test Name
#  820                     Anon94119                      Decipher Invalid Pathology Molecular Test Name
#  821                     Anon74399                      Decipher Invalid Pathology Molecular Test Name
#  824                     Anon86624                      Decipher Invalid Pathology Molecular Test Name
#  825                     Anon96898                   Oncotype DX Invalid Pathology Molecular Test Name
#  826                     Anon43312                      Decipher Invalid Pathology Molecular Test Name
#  827                     Anon25610                      Decipher Invalid Pathology Molecular Test Name
#  828                     Anon90143                   Oncotype DX Invalid Pathology Molecular Test Name
#  829                     Anon56893                      Decipher Invalid Pathology Molecular Test Name
#  830                     Anon21315                   Oncotype DX Invalid Pathology Molecular Test Name
#  832                     Anon16868                   Oncotype DX Invalid Pathology Molecular Test Name
#  833                     Anon74022                   Oncotype DX Invalid Pathology Molecular Test Name
#  835                     Anon52886                   Oncotype DX Invalid Pathology Molecular Test Name
#  836                     Anon58120                      Decipher Invalid Pathology Molecular Test Name
#  839                     Anon14530                      Decipher Invalid Pathology Molecular Test Name
#  840                     Anon93206                   Oncotype DX Invalid Pathology Molecular Test Name
#  841                     Anon11052                   Oncotype DX Invalid Pathology Molecular Test Name
#  842                     Anon35955                      Decipher Invalid Pathology Molecular Test Name
#  843                     Anon55968                   Oncotype DX Invalid Pathology Molecular Test Name
#  845                     Anon32156                      Decipher Invalid Pathology Molecular Test Name
#  846                     Anon93900                   Oncotype DX Invalid Pathology Molecular Test Name
#  850                     Anon94749                      Decipher Invalid Pathology Molecular Test Name
#  851                     Anon14469                   Oncotype DX Invalid Pathology Molecular Test Name
#  853                     Anon35744                      Decipher Invalid Pathology Molecular Test Name
#  854                     Anon86208                   Oncotype DX Invalid Pathology Molecular Test Name
#  856                     Anon27229                      Decipher Invalid Pathology Molecular Test Name
#  857                     Anon96329                   Oncotype DX Invalid Pathology Molecular Test Name
#  858                     Anon30349                   Oncotype DX Invalid Pathology Molecular Test Name
#  859                     Anon64472                   Oncotype DX Invalid Pathology Molecular Test Name
#  861                     Anon10286                      Decipher Invalid Pathology Molecular Test Name
#  863                     Anon17080                   Oncotype DX Invalid Pathology Molecular Test Name
#  866                     Anon40681                      Decipher Invalid Pathology Molecular Test Name
#  868                     Anon75140                      Decipher Invalid Pathology Molecular Test Name
#  869                     Anon18687                   Oncotype DX Invalid Pathology Molecular Test Name
#  872                     Anon44097                      Decipher Invalid Pathology Molecular Test Name
#  873                     Anon29341                      Decipher Invalid Pathology Molecular Test Name
#  874                     Anon89493                   Oncotype DX Invalid Pathology Molecular Test Name
#  875                     Anon46101                      Decipher Invalid Pathology Molecular Test Name
#  877                     Anon23237                      Decipher Invalid Pathology Molecular Test Name
#  878                     Anon29202                   Oncotype DX Invalid Pathology Molecular Test Name
#  879                     Anon92672                      Decipher Invalid Pathology Molecular Test Name
#  881                     Anon94699                      Decipher Invalid Pathology Molecular Test Name
#  882                     Anon74023                      Decipher Invalid Pathology Molecular Test Name
#  884                     Anon80179                      Decipher Invalid Pathology Molecular Test Name
#  888                     Anon31747                      Decipher Invalid Pathology Molecular Test Name
#  890                     Anon34888                   Oncotype DX Invalid Pathology Molecular Test Name
#  891                     Anon25384                      Decipher Invalid Pathology Molecular Test Name
#  893                     Anon65275                      Decipher Invalid Pathology Molecular Test Name
#  894                     Anon13802                      Decipher Invalid Pathology Molecular Test Name
#  896                     Anon16750                      Decipher Invalid Pathology Molecular Test Name
#  900                     Anon34247                      Decipher Invalid Pathology Molecular Test Name
#  901                     Anon98987                   Oncotype DX Invalid Pathology Molecular Test Name
#  902                     Anon98338                      Decipher Invalid Pathology Molecular Test Name
#  904                     Anon62780                      Decipher Invalid Pathology Molecular Test Name
#  905                     Anon41529                   Oncotype DX Invalid Pathology Molecular Test Name
#  906                     Anon98578                   Oncotype DX Invalid Pathology Molecular Test Name
#  908                     Anon21453                      Decipher Invalid Pathology Molecular Test Name
#  910                     Anon12819                   Oncotype DX Invalid Pathology Molecular Test Name
#  911                     Anon32292                      Decipher Invalid Pathology Molecular Test Name
#  912                     Anon22353                      Decipher Invalid Pathology Molecular Test Name
#  913                     Anon55837                   Oncotype DX Invalid Pathology Molecular Test Name
#  915                     Anon16537                      Decipher Invalid Pathology Molecular Test Name
#  917                     Anon11932                   Oncotype DX Invalid Pathology Molecular Test Name
#  918                     Anon47065                      Decipher Invalid Pathology Molecular Test Name
#  919                     Anon17249                   Oncotype DX Invalid Pathology Molecular Test Name
#  920                     Anon31041                      Decipher Invalid Pathology Molecular Test Name
#  921                     Anon70160                   Oncotype DX Invalid Pathology Molecular Test Name
#  922                     Anon64103                   Oncotype DX Invalid Pathology Molecular Test Name
#  924                     Anon71177                   Oncotype DX Invalid Pathology Molecular Test Name
#  927                     Anon23284                      Decipher Invalid Pathology Molecular Test Name
#  929                     Anon77212                   Oncotype DX Invalid Pathology Molecular Test Name
#  931                     Anon42753                   Oncotype DX Invalid Pathology Molecular Test Name
#  932                     Anon42163                      Decipher Invalid Pathology Molecular Test Name
#  936                     Anon58899                   Oncotype DX Invalid Pathology Molecular Test Name
#  937                     Anon43629                      Decipher Invalid Pathology Molecular Test Name
#  940                     Anon29129                      Decipher Invalid Pathology Molecular Test Name
#  942                     Anon97727                      Decipher Invalid Pathology Molecular Test Name
#  943                     Anon96527                   Oncotype DX Invalid Pathology Molecular Test Name
#  944                     Anon21177                   Oncotype DX Invalid Pathology Molecular Test Name
#  945                     Anon72582                      Decipher Invalid Pathology Molecular Test Name
#  946                     Anon99180                   Oncotype DX Invalid Pathology Molecular Test Name
#  947                     Anon75452                      Decipher Invalid Pathology Molecular Test Name
#  949                     Anon24391                      Decipher Invalid Pathology Molecular Test Name
#  951                     Anon33290                   Oncotype DX Invalid Pathology Molecular Test Name
#  954                     Anon30987                      Decipher Invalid Pathology Molecular Test Name
#  955                     Anon72275                   Oncotype DX Invalid Pathology Molecular Test Name
#  956                     Anon64414                      Decipher Invalid Pathology Molecular Test Name
#  957                     Anon57589                   Oncotype DX Invalid Pathology Molecular Test Name
#  958                     Anon95385                      Decipher Invalid Pathology Molecular Test Name
#  960                     Anon54380                      Decipher Invalid Pathology Molecular Test Name
#  961                     Anon67406                      Decipher Invalid Pathology Molecular Test Name
#  962                     Anon12822                      Decipher Invalid Pathology Molecular Test Name
#  963                     Anon72619                      Decipher Invalid Pathology Molecular Test Name
#  964                     Anon65590                      Decipher Invalid Pathology Molecular Test Name
#  965                     Anon29774                      Decipher Invalid Pathology Molecular Test Name
#  967                     Anon43356                      Decipher Invalid Pathology Molecular Test Name
#  969                     Anon63563                      Decipher Invalid Pathology Molecular Test Name
#  971                     Anon51032                      Decipher Invalid Pathology Molecular Test Name
#  973                     Anon98914                   Oncotype DX Invalid Pathology Molecular Test Name
#  977                     Anon34544                      Decipher Invalid Pathology Molecular Test Name
#  978                     Anon20802                      Decipher Invalid Pathology Molecular Test Name
#  980                     Anon59447                   Oncotype DX Invalid Pathology Molecular Test Name
#  982                     Anon25764                      Decipher Invalid Pathology Molecular Test Name
#  984                     Anon44540                      Decipher Invalid Pathology Molecular Test Name
#  985                     Anon19078                   Oncotype DX Invalid Pathology Molecular Test Name
#  986                     Anon16116                   Oncotype DX Invalid Pathology Molecular Test Name
#  988                     Anon47108                   Oncotype DX Invalid Pathology Molecular Test Name
#  989                     Anon52154                   Oncotype DX Invalid Pathology Molecular Test Name
#  990                     Anon54224                   Oncotype DX Invalid Pathology Molecular Test Name
#  991                     Anon75978                   Oncotype DX Invalid Pathology Molecular Test Name
#  993                     Anon10856                   Oncotype DX Invalid Pathology Molecular Test Name
#  994                     Anon13252                   Oncotype DX Invalid Pathology Molecular Test Name
#  996                     Anon85064                      Decipher Invalid Pathology Molecular Test Name
#  997                     Anon43386                   Oncotype DX Invalid Pathology Molecular Test Name
#  998                     Anon18430                      Decipher Invalid Pathology Molecular Test Name
# 3. No missing 'Pathology Molecular Test Name' values found (null values are allowed).
#
# Validating for DiagStaging_PathologyMolecularTestResult
# 1. Recognized 'Pathology Molecular Test Result' as 'DiagStaging_PathologyMolecularTestResult' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStaging_PathologyMolecularTestResult'
# 2. No rows with invalid Pathology Molecular Test Result values found.
#
# 3. No missing 'Pathology Molecular Test Result' values found (null values are allowed).
#
# Validating for PatientTreatmentOutcome_DiseaseStatus
# 1. Recognized 'Treatment Outcome' as 'PatientTreatmentOutcome_DiseaseStatus' for validation, but the column name is incorrect.
#    The correct column name should be 'PatientTreatmentOutcome_DiseaseStatus'
# 2. No rows with invalid Treatment Outcome values found.
#
# 3. No missing 'Treatment Outcome' values found.
#
# Validating for DiagStagingTreatmentOverview_DateOfRecord
# 1. Recognized 'Start Date of Treatment' as 'DiagStagingTreatmentOverview_DateOfRecord' for validation, but the column name is incorrect.
#    The correct column name should be 'DiagStagingTreatmentOverview_DateOfRecord'
# 2. No rows with invalid Start Date of Treatment values found.
#
# 3. No missing 'Start Date of Treatment' values found.
#
# Validating for PatientTreatmentOutcome_DateOfRecord
# 1. Recognized 'End Date of Treatment' as 'PatientTreatmentOutcome_DateOfRecord' for validation, but the column name is incorrect.
#    The correct column name should be 'PatientTreatmentOutcome_DateOfRecord'
# 2. No rows with invalid End Date of Treatment values found.
#
# 3. No missing 'End Date of Treatment' values found (null values are not allowed).
