# %%
import pandas as pd

dataset = pd.read_excel('Hospital Patient Dataset Validata.xlsx')
dataset
# Out:
#      Patient MRN Anonymized Patient Identifier Date of Birth  Year of Birth  \
# 0            NaN                     Anon70998    04/12/1996            NaN
# 1      8942976.0                           NaN    14/08/1983         1983.0
# 2            NaN                     Anon98591    15/09/1952            NaN
# 3      9249111.0                     Anon35408    1962-01-18         1962.0
# 4      2971959.0                     Anon65131    1962-01-18         1962.0
# ..           ...                           ...           ...            ...
# 295          NaN                     Anon43918    27/04/1941         1941.0
# 296    2533581.0                     Anon63054    27/11/1992         1992.0
# 297          NaN                     Anon34333    27/12/1983         1983.0
# 298    4924162.0                     Anon85985    29/10/1998         1998.0
# 299          NaN                           NaN    30/08/1931            NaN
#
# ...

# %%
print(dataset.columns)
# Out:
# Index(['Patient MRN', 'Anonymized Patient Identifier', 'Date of Birth',
#        'Year of Birth', 'Date of Death', 'Age At Date of Death',
#        'Cause of Death', 'Cause of Death Attributable to Treatment',
#        'Sex at Birth', 'Patient Reported Race', 'Patient Reported Ethnicity',
#        'Vital Status', 'Gender Identity', 'Has tobacco use history',
#        'Height (cm)', 'Weight (kg)', 'Smoking Pack Years', 'Blood Pressure',
#        'Heart Rate (bpm)', 'Temperature (Celsius)', 'On Clinical Trial',
#        'Clinical Trial Numbers', 'Postal Code of Domicile', 'Education Level',
#        'Primary Language Spoken at Home', 'Disability', 'Date of Record',
#        'Age at Record', 'Staging System', 'ICD Version', 'ICD Code',
#        'Histology', 'Staging-T Category', 'Staging-T', 'Staging-N',
#        'Staging-M', 'Imaging for Biopsy', 'Pathology Molecular Test Name',
#        'Pathology Molecular Test Result', 'Treatment Course ID',
# ...

# %%
from datetime import datetime

# %%
import pandas as pd

# Load the dataset
dataset = pd.read_excel('Hospital Patient Dataset Validata.xlsx')

# Step 1: Recognize and validate the 'Patient MRN' column
def find_equivalent_column_mrn(data, expected_column):
    alternative_names = ["Patient MRN", "MRN", "Medical Record Number"]  # Add more alternatives if needed
    for col in data.columns:
        if col in alternative_names:
            print(f"1. Recognized '{col}' as '{expected_column}' for validation, but the column name is incorrect.")
            print(f"   The correct column name should be: '{expected_column}'")
            return col  # Return the recognized column
    print(f"1. Column name mismatch: Expected '{expected_column}', but not found in dataset.")
    print(f"   Found columns: {list(data.columns)}")
    print(f"   The correct column name should be: '{expected_column}'")
    return None

# Step 2: Validate the 'Patient MRN' values (ensure they are non-null and in string format)
def validate_mrn_values(data, mrn_column):
    invalid_mrn = []

    for index, row in data.iterrows():
        mrn_value = row[mrn_column]

        # Check if MRN is not null and is in string format
        if pd.isna(mrn_value) or not isinstance(mrn_value, str):
            invalid_mrn.append({
                'Row': index,
                'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
                mrn_column: mrn_value,
                'Error': 'Invalid or missing MRN value'
            })

    return pd.DataFrame(invalid_mrn)

# Step 3: Check if both 'Patient MRN' and 'Anonymized Patient Identifier' are missing
def validate_missing_mrn_or_anonymized_id(data, mrn_column, anon_id_column='Anonymized Patient Identifier'):
    both_missing = data[data[mrn_column].isna() & data[anon_id_column].isna()]
    if not both_missing.empty:
        print(f"3. Rows where both '{mrn_column}' and '{anon_id_column}' are missing:")
        print(both_missing[[anon_id_column, mrn_column]])
    else:
        print(f"3. No rows found where both '{mrn_column}' and '{anon_id_column}' are missing.")

# Run the validation functions for 'Patient MRN'
expected_column_mrn = 'Patient_MRN'

# Step 1: Recognize and handle equivalent columns for 'Patient MRN'
recognized_column_mrn = find_equivalent_column_mrn(dataset, expected_column_mrn)

# If an equivalent column is recognized, proceed with the validation
if recognized_column_mrn:
    # Step 2: Validate the values in the 'Patient MRN' column
    invalid_mrn = validate_mrn_values(dataset, recognized_column_mrn)
    
    # Output the number of invalid rows
    invalid_count_mrn = len(invalid_mrn)
    if invalid_count_mrn > 0:
        invalid_row_numbers = invalid_mrn['Row'].tolist()
        invalid_row_numbers_str = ','.join(map(str, invalid_row_numbers))

        print(f"2. {invalid_count_mrn} rows have an invalid MRN value:")
        print(f"   Row numbers: {invalid_row_numbers_str}\n")
        print(invalid_mrn.to_string(index=False))  # Output invalid rows without index
    else:
        print(f"2. No rows with invalid MRN values found.\n")

    # Step 3: Check if both 'Patient MRN' and 'Anonymized Patient Identifier' are missing
    validate_missing_mrn_or_anonymized_id(dataset, recognized_column_mrn)
# Out:
# 1. Recognized 'Patient MRN' as 'Patient_MRN' for validation, but the column name is incorrect.
#    The correct column name should be: 'Patient_MRN'
# 2. 300 rows have an invalid MRN value:
# ...

# %%
import pandas as pd

# Load the dataset
dataset = pd.read_excel('Hospital Patient Dataset Validata.xlsx')

# Step 1: Function to recognize columns and flag incorrect names
def find_equivalent_column(data, expected_column, alternative_names):
    for col in data.columns:
        if col in alternative_names:
            print(f"1. Recognized '{col}' as '{expected_column}' for validation, but the column name is incorrect.")
            print(f"   The correct column name should be '{expected_column}'")
            return col  # Return the recognized column
    print(f"1. Column name mismatch: Expected '{expected_column}', but not found in dataset.")
    print(f"   Found columns: {list(data.columns)}")
    print(f"   The correct column name should be '{expected_column}'")
    return None

# Step 2: Validate MRN and Anonymized Patient Identifier values with specific output
def validate_values(data, mrn_column, anon_id_column):
    invalid_rows = []

    for index, row in data.iloc[1:].iterrows():  # Start from row 2
        mrn_value = row[mrn_column]
        anon_id_value = row[anon_id_column]

        # Check MRN value
        if pd.notna(mrn_value):
            mrn_str = str(int(mrn_value)) if isinstance(mrn_value, float) else str(mrn_value).strip()
            if not mrn_str.isalnum() or len(mrn_str) > 20:
                invalid_rows.append({
                    'Row': index + 1,
                    'Column': mrn_column,
                    'Value': mrn_value,
                    'Error': 'Invalid Patient MRN'
                })

        # Check Anonymized Patient Identifier value
        if pd.notna(anon_id_value):
            anon_id_str = str(anon_id_value).strip()
            if not anon_id_str.isalnum() or len(anon_id_str) > 20:
                invalid_rows.append({
                    'Row': index + 1,
                    'Column': anon_id_column,
                    'Value': anon_id_value,
                    'Error': 'Invalid Anonymized Patient Identifier'
                })

    return pd.DataFrame(invalid_rows)

# Step 3: Check for missing values in both MRN and Anonymized ID columns
def validate_missing_identifiers(data, mrn_column, anon_id_column):
    missing_rows = data.iloc[1:][data[mrn_column].isna() & data[anon_id_column].isna()]

    if not missing_rows.empty:
        print(f"3. {len(missing_rows)} rows with both '{mrn_column}' and '{anon_id_column}' missing:")
        row_numbers = [index + 1 for index in missing_rows.index]
        print(f"   Row numbers: {', '.join(map(str, row_numbers))}\n")

        for index, row in missing_rows.iterrows():
            print(f"Row {index + 1}: Anonymized Patient Identifier = {row[anon_id_column]}, {mrn_column} = NaN")
    else:
        print(f"3. No rows with both '{mrn_column}' and '{anon_id_column}' missing.")

# Define expected columns and their alternatives
expected_column_mrn = 'Patient_MRN'
mrn_alternatives = ["Patient MRN", "MRN"]

expected_column_anon_id = 'Patient_AnonPatID'
anon_id_alternatives = ["Anonymized Patient Identifier", "Anon Patient ID"]

# Step 1: Recognize the columns for validation
recognized_column_mrn = find_equivalent_column(dataset, expected_column_mrn, mrn_alternatives)
recognized_column_anon_id = find_equivalent_column(dataset, expected_column_anon_id, anon_id_alternatives)

# Proceed with the validation if both columns are recognized
if recognized_column_mrn and recognized_column_anon_id:
    # Step 2: Validate the values in both columns
    invalid_values = validate_values(dataset, recognized_column_mrn, recognized_column_anon_id)

    if not invalid_values.empty:
        print(f"2. {len(invalid_values)} rows have invalid values in '{recognized_column_mrn}' or '{recognized_column_anon_id}':")
        invalid_row_numbers = invalid_values['Row'].tolist()
        print(f"   Row numbers: {', '.join(map(str, invalid_row_numbers))}\n")
        print(invalid_values.to_string(index=False))
    else:
        print(f"2. No rows with invalid '{recognized_column_mrn}' or '{recognized_column_anon_id}' values found.\n")

    # Step 3: Re-run the missing value check
    validate_missing_identifiers(dataset, recognized_column_mrn, recognized_column_anon_id)
# Out:
# 1. Recognized 'Patient MRN' as 'Patient_MRN' for validation, but the column name is incorrect.
#    The correct column name should be 'Patient_MRN'
# 1. Recognized 'Anonymized Patient Identifier' as 'Patient_AnonPatID' for validation, but the column name is incorrect.
#    The correct column name should be 'Patient_AnonPatID'
# 2. No rows with invalid 'Patient MRN' or 'Anonymized Patient Identifier' values found.
#
# 3. 20 rows with both 'Patient MRN' and 'Anonymized Patient Identifier' missing:
#    Row numbers: 14, 68, 70, 127, 128, 129, 131, 156, 161, 181, 191, 215, 243, 246, 251, 254, 269, 288, 289, 300
#
# Row 14: Anonymized Patient Identifier = nan, Patient MRN = NaN
# Row 68: Anonymized Patient Identifier = nan, Patient MRN = NaN
# Row 70: Anonymized Patient Identifier = nan, Patient MRN = NaN
# Row 127: Anonymized Patient Identifier = nan, Patient MRN = NaN
# Row 128: Anonymized Patient Identifier = nan, Patient MRN = NaN
# ...

# %%
import pandas as pd

# Load the dataset
dataset = pd.read_excel('Hospital Patient Dataset Validata.xlsx')

# Step 1: Function to recognize 'Date of Birth' as 'Patient_DateOfBirth' and flag incorrect names
def find_equivalent_column(data, expected_column):
    alternative_names = ["Date of Birth", "DOB", "Birthdate"]  # Add more alternatives as needed
    for col in data.columns:
        if col in alternative_names:
            print(f"1. Recognized '{col}' as '{expected_column}' for validation, but the column name is incorrect.")
            return col  # Return the recognized column
    print(f"1. Column name mismatch: Expected '{expected_column}', but not found in dataset.")
    print(f"   Found columns: {list(data.columns)}")
    return None

# Step 2: Convert correctly formatted ISO 8601 strings (including date-only format) to datetime, flag invalid strings
def convert_or_flag_dates(data, dob_column):
    invalid_dob = []

    # Try to convert each value to datetime if it's a string
    for index, row in data.iterrows():
        dob = row[dob_column]

        # Check if the type of 'dob' is string and try to convert to datetime
        if isinstance(dob, str):
            try:
                # Attempt to parse the date (allowing both date-only and datetime format)
                parsed_dob = pd.to_datetime(dob, format="%Y-%m-%d", errors='raise')  # Allow date-only format
                # If conversion is successful, replace the string with the datetime object
                data.at[index, dob_column] = parsed_dob
            except Exception:
                # If parsing fails, flag the error
                invalid_dob.append({
                    'Row': index,
                    'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
                    dob_column: dob,
                    'Error': 'Invalid ISO 8601 format'
                })

    # Return the DataFrame with invalid rows
    return pd.DataFrame(invalid_dob)

# Step 3: Check for missing 'Patient_DateOfBirth' values
def validate_missing_dates(data, dob_column):
    missing_dob = data[data[dob_column].isna()]
    if not missing_dob.empty:
        print(f"3. Rows with missing '{dob_column}':")
        print(missing_dob[['Anonymized Patient Identifier', dob_column]])
    else:
        print(f"3. No missing '{dob_column}' values found.")

# Run the validation functions
expected_column = 'Patient_DateOfBirth'

# Step 1: Recognize and handle equivalent columns for 'Patient_DateOfBirth'
recognized_column = find_equivalent_column(dataset, expected_column)

# If an equivalent column is recognized, proceed with the validation
if recognized_column:
    # Step 2: Convert correctly formatted strings (including date-only) to datetime, flag invalid strings
    invalid_dates = convert_or_flag_dates(dataset, recognized_column)
    
    # Output the number of invalid rows
    invalid_count = len(invalid_dates)
    if invalid_count > 0:
        # Extract just the row numbers
        invalid_row_numbers = invalid_dates['Row'].tolist()
        invalid_row_numbers_str = ','.join(map(str, invalid_row_numbers))

        # Display the count and the row numbers
        print(f"2. {invalid_count} rows have an invalid ISO 8601 format:")
        print(f"   Row numbers: {invalid_row_numbers_str}\n")

        # Output the detailed list of invalid rows
        print(invalid_dates.to_string(index=False))  # Output invalid rows without index
    else:
        print(f"2. No rows with invalid ISO 8601 format found.\n")

    # Step 3: Re-run the missing value check
    validate_missing_dates(dataset, recognized_column)
# Out:
# 1. Recognized 'Date of Birth' as 'Patient_DateOfBirth' for validation, but the column name is incorrect.
# 2. 49 rows have an invalid ISO 8601 format:
#    Row numbers: 0,1,2,13,14,15,43,44,45,46,68,69,70,95,96,97,98,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,274,287,288,289,290,291,292,293,294,295,296,297,298,299
#
#  Row Anonymized Patient Identifier Date of Birth                   Error
#    0                     Anon70998    04/12/1996 Invalid ISO 8601 format
#    1                           NaN    14/08/1983 Invalid ISO 8601 format
#    2                     Anon98591    15/09/1952 Invalid ISO 8601 format
#   13                           NaN    28/03/1943 Invalid ISO 8601 format
#   14                     Anon35590    03/02/1995 Invalid ISO 8601 format
#   15                     Anon58370    14/07/1975 Invalid ISO 8601 format
#   43                     Anon74403    26/01/1941 Invalid ISO 8601 format
# ...

# %%
import pandas as pd

# Load the dataset
dataset = pd.read_excel('Hospital Patient Dataset Validata.xlsx')

# Step 1: Function to recognize 'Date of Birth' as 'Patient_DateOfBirth' and flag incorrect names
def find_equivalent_column(data, expected_column):
    alternative_names = ["Date of Birth", "DOB", "Birthdate"]  # Add more alternatives as needed
    for col in data.columns:
        if col in alternative_names:
            print(f"1. Recognized '{col}' as '{expected_column}' for validation, but the column name is incorrect.")
            print(f"   Expected ISO 8601 format: 'YYYY-MM-DD' (date only, no time)")
            return col  # Return the recognized column
    print(f"1. Column name mismatch: Expected '{expected_column}', but not found in dataset.")
    print(f"   Found columns: {list(data.columns)}")
    return None

# Step 2: Convert correctly formatted ISO 8601 strings (including date-only format) to datetime, flag invalid strings
def convert_or_flag_dates(data, dob_column):
    invalid_dob = []

    # Try to convert each value to datetime if it's a string
    for index, row in data.iterrows():
        dob = row[dob_column]

        # Check if the type of 'dob' is string and try to convert to datetime
        if isinstance(dob, str):
            try:
                # Attempt to parse the date with the specified format
                parsed_dob = pd.to_datetime(dob, format="%Y-%m-%d", errors='raise')
                # If conversion is successful, replace the string with the datetime object
                data.at[index, dob_column] = parsed_dob
            except Exception:
                # If parsing fails, flag the error
                invalid_dob.append({
                    'Row': index,
                    'Anonymized Patient Identifier': row['Anonymized Patient Identifier'],
                    dob_column: dob,
                    'Error': 'Invalid format. Expected ISO 8601 format: YYYY-MM-DD'
                })

    # Return the DataFrame with invalid rows
    return pd.DataFrame(invalid_dob)

# Step 3: Check for missing 'Patient_DateOfBirth' values
def validate_missing_dates(data, dob_column):
    missing_dob = data[data[dob_column].isna()]
    if not missing_dob.empty:
        print(f"3. Rows with missing '{dob_column}':")
        print(missing_dob[['Anonymized Patient Identifier', dob_column]])
    else:
        print(f"3. No missing '{dob_column}' values found.")

# Run the validation functions
expected_column = 'Patient_DateOfBirth'

# Add validation message
print(f"Validating for {expected_column}")

# Step 1: Recognize and handle equivalent columns for 'Patient_DateOfBirth'
recognized_column = find_equivalent_column(dataset, expected_column)

# If an equivalent column is recognized, proceed with the validation
if recognized_column:
    # Step 2: Convert correctly formatted strings (including date-only) to datetime, flag invalid strings
    invalid_dates = convert_or_flag_dates(dataset, recognized_column)
    
    # Output the number of invalid rows
    invalid_count = len(invalid_dates)
    if invalid_count > 0:
        # Extract just the row numbers
        invalid_row_numbers = invalid_dates['Row'].tolist()
        invalid_row_numbers_str = ','.join(map(str, invalid_row_numbers))

        # Display the count and the row numbers
        print(f"2. {invalid_count} rows have an invalid ISO 8601 format:")
        print(f"   Expected format: YYYY-MM-DD (no time component)")
        print(f"   Row numbers: {invalid_row_numbers_str}\n")

        # Output the detailed list of invalid rows
        print(invalid_dates.to_string(index=False))  # Output invalid rows without index
    else:
        print(f"2. No rows with invalid ISO 8601 format found.\n")

    # Step 3: Re-run the missing value check
    validate_missing_dates(dataset, recognized_column)
# Out:
# Validating for Patient_DateOfBirth
# 1. Recognized 'Date of Birth' as 'Patient_DateOfBirth' for validation, but the column name is incorrect.
#    Expected ISO 8601 format: 'YYYY-MM-DD' (date only, no time)
# 2. 49 rows have an invalid ISO 8601 format:
#    Expected format: YYYY-MM-DD (no time component)
#    Row numbers: 0,1,2,13,14,15,43,44,45,46,68,69,70,95,96,97,98,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,274,287,288,289,290,291,292,293,294,295,296,297,298,299
#
#  Row Anonymized Patient Identifier Date of Birth                                                Error
#    0                     Anon70998    04/12/1996 Invalid format. Expected ISO 8601 format: YYYY-MM-DD
#    1                           NaN    14/08/1983 Invalid format. Expected ISO 8601 format: YYYY-MM-DD
#    2                     Anon98591    15/09/1952 Invalid format. Expected ISO 8601 format: YYYY-MM-DD
# ...
